# %%
import numpy as np
import pandas as pd
import datetime as dt
from vnstock import *
import requests

# %%
listing = pd.read_excel('listing.xlsx')

# %%
listing.to_excel('listing.xlsx')

# %%
overview = []
for i in listing['ticker']:
    i_overview = ticker_overview(i).values.tolist()
    overview += i_overview
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\NAMTRA~1\AppData\Local\Temp/ipykernel_10700/4060854683.py in <module>
#       1 overview = []
#       2 for i in listing['ticker']:
# ----> 3     i_overview = ticker_overview(i).values.tolist()
#       4     overview += i_overview
#
# ~\Anaconda3\lib\site-packages\vnstock\stock.py in ticker_overview(symbol)
#      46
#      47 def ticker_overview (symbol):
# ---> 48     data = requests.get('https://apipubaws.tcbs.com.vn/tcanalysis/v1/ticker/{}/overview'.format(symbol)).json()
#      49     df = json_normalize(data)
#      50     return df
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
# ...

# %%
overview_df = pd.DataFrame(overview, columns = ticker_overview('SHS').columns)

# %%
overview_df.head()

# %%
overview_df.to_excel('overview.xlsx')

# %%
price_board('TCB,SSI,VND')
# Out:
#   Mã CP  Giá Khớp Lệnh  KLBD/TB5D  T.độ GD  KLGD ròng(CM)  %KLGD ròng (CM)  \
# 0   TCB        28350.0       1.66     2.02         -85200            -19.7
# 1   SSI        21500.0       1.60     6.34        3155800             40.3
# 2   VND        15500.0       1.37     4.80        1489100             22.7
#
#          RSI  MACD Volume MACD Signal Tín hiệu KT  ... Khối lượng Dư mua  \
# 0  61.260158         0.21         Buy         Buy  ...            404600
# 1  63.750656         0.15         Buy        Sell  ...            286100
# 2  58.532234         0.08     Neutral     Neutral  ...            679300
#
#    Khối lượng Dư bán  Khớp nhiều nhất         seq  vnid3d  vnid1m  vnid3m  \
# 0            1085600            28350  1680249540     0.5     3.7     5.0
# 1            1872300            21500  1680249540     0.5     3.7     5.0
# 2            1857500            15500  1680249540     0.5     3.7     5.0
#
#    vnid1y    vnipe    vnipb
# 0   -29.3  12.0036  1.58003
# ...

# %%
# %%time
price = []
for i in listing['ticker']:
    i_price = price_board(i).values.tolist()
    price += i_price
# Out:
# Wall time: 8min 2s

# %%
price_df = pd.DataFrame(price, columns = price_board('SHS').columns)

# %%
price_df
# Out:
#      Mã CP  Giá Khớp Lệnh  KLBD/TB5D  T.độ GD  KLGD ròng(CM)  %KLGD ròng (CM)  \
# 0      VVS            0.0       0.00     0.00            0.0              0.0
# 1      XDC            NaN        NaN      NaN            NaN              NaN
# 2      HSV         3800.0       9.09     0.00            0.0              0.0
# 3      CST        20900.0       2.07     1.31            0.0              0.0
# 4      BVL         9900.0       0.42     0.00            0.0              0.0
# ...    ...            ...        ...      ...            ...              ...
# 1619   XMP        18400.0       0.28     0.00            0.0              0.0
# 1620   YBC            0.0       0.00     0.00            0.0              0.0
# 1621   YBM         6050.0       0.10     0.00            0.0              0.0
# 1622   YEG         9980.0       0.48     0.48            0.0              0.0
# 1623   YTC            0.0       0.00     0.00            0.0              0.0
#
# ...

# %%
price_df.to_excel('price_df.xlsx')

# %%
financial_flow(symbol="SGN", report_type='cashflow', report_range='quarterly')
# Out:
#         ticker  investCost  fromInvest  fromFinancial  fromSale  freeCashFlow
# index
# 2022-Q4    SGN          -5        -172              0        75         286.0
# 2022-Q3    SGN          -3         101            -84        43         147.0
# 2022-Q2    SGN           0         -49              0        71         109.0
# 2022-Q1    SGN           0        -188              0        -4         143.0
# 2021-Q4    SGN           0           2            -84       161         145.0
# 2021-Q3    SGN           0           2              0       -10         105.0
# 2021-Q2    SGN           0           2              0        22         120.0
# 2021-Q1    SGN           0           2              0        15         137.0
# 2020-Q4    SGN          62         194           -141        25         196.0
# 2020-Q3    SGN         -62         -97             -7        44         139.0
# 2020-Q2    SGN         -37          16              0       -38         331.0
# ...
